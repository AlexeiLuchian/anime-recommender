# %%
import pandas as pd
import pickle
from pathlib import Path
import sys

sys.path.append('../src')
from recommender import search_anime, get_recommendations

with open('../models/content_recommender.pkl', 'rb') as f:
    recommender_data = pickle.load(f)

similarity_df = recommender_data['similarity_df']
titles = recommender_data['titles']
X_features = recommender_data['X_features']

print("Recommender loaded!")
print(f"Ready to recommend from {len(titles)} anime")
# Out:
# Recommender function created!
# Search function created!
# Recommender loaded!
# Ready to recommend from 1050 anime

# %%
search_anime(titles, "naruto")

test_anime = "Boruto: Naruto Next Generations"
recs = get_recommendations(test_anime, titles, similarity_df, n_recommendations=5)
print(recs)
# Out:
# Found 11 anime matching 'naruto':
#   -> Naruto
#   -> Naruto Shippuden
#   -> Boruto: Naruto Next Generations
#   -> Naruto Shippuden the Movie 7: The Last
#   -> Boruto: Naruto the Movie
#   -> Naruto Shippuden the Movie 6: Road to Ninja
#   -> Naruto the Movie 1: Ninja Clash in the Land of Snow
#   -> Naruto Shippuden the Movie 1
#   -> Naruto Shippuden the Movie 2: Bonds
#   -> Naruto Shippuden the Movie 4: The Lost Tower
#   -> Naruto Shippuden the Movie 5: Blood Prison
#    Rank                                              Anime  Similarity Score  \
# 0     1                                  Dragon Ball Super          0.863170
# 1     2                       Magi: The Labyrinth of Magic          0.717782
# 2     3  The Seven Deadly Sins: Imperial Wrath of the Gods          0.715125
# 3     4                          Magi: Adventure of Sinbad          0.710828
# 4     5           The Seven Deadly Sins: Signs of Holy War          0.708739
#
#    Match %
# 0     86.3
# 1     71.8
# 2     71.5
# 3     71.1
# 4     70.9
